# %%
import hashlib
import json
import os
import datetime

# ------------------------------
# 1. Calculate SHA-256 hash
# ------------------------------
def calculate_hash(file_path):
    sha256 = hashlib.sha256()
    try:
        with open(file_path, "rb") as f:
            while chunk := f.read(4096):
                sha256.update(chunk)
        return sha256.hexdigest()
    except FileNotFoundError:
        return None


# ------------------------------
# 2. Store initial hashes
# ------------------------------
def store_hashes(file_paths, db_file="hashes.json"):
    hashes = {}
    for file_path in file_paths:
        file_hash = calculate_hash(file_path)
        if file_hash:
            hashes[file_path] = file_hash
    with open(db_file, "w") as f:
        json.dump(hashes, f)
    print(f"[+] Hashes stored in {db_file}")


# ------------------------------
# 3. Verify all files
# ------------------------------
def verify_all(db_file="hashes.json"):
    if not os.path.exists(db_file):
        print("[-] No stored hashes found. Run option 1 first.")
        return None

    with open(db_file, "r") as f:
        stored_hashes = json.load(f)

    results = {}
    for file_path, old_hash in stored_hashes.items():
        new_hash = calculate_hash(file_path)
        if not new_hash:
            status = "File not found"
        elif old_hash == new_hash:
            status = "SAFE"
        else:
            status = "MODIFIED"
        results[file_path] = status
        print(f"{file_path} → {status}")
    return results


# ------------------------------
# 4. Generate forensic report (UTF-8 safe)
# ------------------------------
def generate_report(results, report_dir="."):
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    report_name = f"Forensic_Report_{timestamp}.txt"
    report_path = os.path.join(report_dir, report_name)

    # ✅ UTF-8 encoding to avoid UnicodeEncodeError
    with open(report_path, "w", encoding="utf-8") as report:
        for file_path, status in results.items():
            line = f"{file_path} → {status}\n"
            report.write(line)

    print(f"\n[+] Forensic report saved at: {report_path}")


# ------------------------------
# 5. Menu-driven interface
# ------------------------------
while True:
    print("\n==== File Integrity Monitoring Tool ====")
    print("1. Store file hashes")
    print("2. Verify all files")
    print("3. Exit")
    
    choice = input("Enter your choice (1/2/3): ")
    
    if choice == "1":
        files = input("Enter file paths separated by commas: ").split(",")
        files = [f.strip() for f in files]  # clean spaces
        store_hashes(files)
    
    elif choice == "2":
        results = verify_all()
        if results:
            # Change folder path below to where you want reports
            generate_report(results, "C:/Users/kanad/Desktop/CSDF ASSI")
    
    elif choice == "3":
        print("Exiting program...")
        break
    
    else:
        print("Invalid choice, try again.")
# Out:
# ==== File Integrity Monitoring Tool ====
# 1. Store file hashes
# 2. Verify all files
# 3. Exit
# Enter your choice (1/2/3):  1
# Enter file paths separated by commas:  C:\Users\kanad\Desktop\CSDFASSI\Another text for prj.txt,C:\Users\kanad\Desktop\CSDFASSI\For MINI prj.txt
# [+] Hashes stored in hashes.json
#
# ==== File Integrity Monitoring Tool ====
# 1. Store file hashes
# 2. Verify all files
# 3. Exit
# Enter your choice (1/2/3):  2
# C:\Users\kanad\Desktop\CSDFASSI\Another text for prj.txt → SAFE
# C:\Users\kanad\Desktop\CSDFASSI\For MINI prj.txt → SAFE
#
# [+] Forensic report saved at: C:/Users/kanad/Desktop/CSDF ASSI\Forensic_Report_2025-10-31_13-38-39.txt
#
# ==== File Integrity Monitoring Tool ====
# 1. Store file hashes
# 2. Verify all files
# 3. Exit
# Enter your choice (1/2/3):  2
# C:\Users\kanad\Desktop\CSDFASSI\Another text for prj.txt → SAFE
# C:\Users\kanad\Desktop\CSDFASSI\For MINI prj.txt → MODIFIED
#
# ...

# %%
C:\Users\kanad\Desktop\CSDFASSI\Another text for prj.txt,C:\Users\kanad\Desktop\CSDFASSI\For MINI prj.txt
